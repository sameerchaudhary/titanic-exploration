# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# data processing 
from sklearn import preprocessing

# plotting scatter plot for all the features 
from pandas.plotting import scatter_matrix

# metrics
from sklearn import metrics

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
train_dataset = pd.read_csv('train.csv')
test_dataset = pd.read_csv("test.csv")
print(train_dataset.info())
train_dataset.head(n=20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# ...

# %%
pd.concat([train_dataset.isnull().sum(), test_dataset.isnull().sum()], axis=1, keys=['Train Dataset', 'Test Dataset'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.
#              Train Dataset  Test Dataset
# Age                    177          86.0
# Cabin                  687         327.0
# Embarked                 2           0.0
# Fare                     0           1.0
# Name                     0           0.0
# Parch                    0           0.0
# PassengerId              0           0.0
# Pclass                   0           0.0
# Sex                      0           0.0
# SibSp                    0           0.0
# Survived                 0           NaN
# Ticket                   0           0.0

# %%
print(train_dataset.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#train_dataset["ticket_prefix"], train_dataset["ticket_number"] = train_dataset["Ticket"].str.split(" ").str
train_dataset["Ticket"].str.split(" ")
# Out:
# 0             [A/5, 21171]
# 1              [PC, 17599]
# 2      [STON/O2., 3101282]
# 3                 [113803]
# 4                 [373450]
# 5                 [330877]
# 6                  [17463]
# 7                 [349909]
# 8                 [347742]
# 9                 [237736]
# 10              [PP, 9549]
# 11                [113783]
# 12            [A/5., 2151]
# 13                [347082]
# 14                [350406]
# 15                [248706]
# 16                [382652]
# 17                [244373]
# 18                [345763]
# 19                  [2649]
# 20                [239865]
# 21                [248698]
# 22                [330923]
# 23                [113788]
# 24                [349909]
# 25                [347077]
# 26                  [2631]
# 27                 [19950]
# 28                [330959]
# 29                [349216]
#               ...
# 861                [28134]
# 862                [17466]
# 863            [CA., 2343]
# ...

# %%
uniqueVal = {}
for col in train_dataset.columns:
    print(col,len(train_dataset[col].unique()))
# Out:
# PassengerId 891
# Survived 2
# Pclass 3
# Name 891
# Sex 2
# Age 89
# SibSp 7
# Parch 7
# Ticket 681
# Fare 248
# Cabin 148
# Embarked 4

# %%
#train_dataset[["Embarked"]].isnull().any(axis=1)
train_dataset[train_dataset[["Embarked"]].isnull().any(axis=1)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_dataset[train_dataset["Survived"]==1].shape
# Out:
# (342, 12)

# %%
train_dataset.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass  \
# count    891.000000  891.000000  891.000000
# unique          NaN         NaN         NaN
# top             NaN         NaN         NaN
# freq            NaN         NaN         NaN
# mean     446.000000    0.383838    2.308642
# std      257.353842    0.486592    0.836071
# min        1.000000    0.000000    1.000000
# 25%      223.500000    0.000000    2.000000
# 50%      446.000000    0.000000    3.000000
# 75%      668.500000    1.000000    3.000000
# max      891.000000    1.000000    3.000000
#
#                                          Name   Sex         Age       SibSp  \
# count                                     891   891  714.000000  891.000000
# unique                                    891     2         NaN         NaN
# top     Lindahl, Miss. Agda Thorilda Viktoria  male         NaN         NaN
# freq                                        1   577         NaN         NaN
# ...

# %%
train_dataset.describe(include=["O"])
# Out:
#                                          Name   Sex  Ticket        Cabin  \
# count                                     891   891     891          204
# unique                                    891     2     681          147
# top     Lindahl, Miss. Agda Thorilda Viktoria  male  347082  C23 C25 C27
# freq                                        1   577       7            4
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
